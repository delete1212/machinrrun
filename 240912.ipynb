# %%
import numpy as np

I = [1,2,3,4]
x = np.array(I)

type(x)
x.ndim
x.shape
np.arange(0,11,2,dtype='float')
np.linspace(0,5,5)
np.random.rand(2)
N=np.random.rand(2,3)
N
# Out:
# array([[5.62655872e-01, 9.14078702e-01, 6.81487390e-01],
#        [3.14809383e-04, 3.47789515e-01, 6.47117751e-02]])

# %%
N.max()
# Out:
# 0.9140787022555361

# %%
N.min()
# Out:
# 0.0003148093830754872

# %%
N.sum()
# Out:
# 2.571038063392369

# %%
N.mean()
# Out:
# 0.42850634389872816

# %%
N.argmax()
# Out:
# 1

# %%
np.random.randint(1,7)
# Out:
# 3

# %%
np.random.randint(1,100,(3,4))
# Out:
# array([[38, 80, 83, 78],
#        [47, 78, 47, 77],
#        [59, 63, 71, 45]])

# %%
m=np.array(([5,10,15],[20,25,30],[35,40,45]))
m
# Out:
# array([[ 5, 10, 15],
#        [20, 25, 30],
#        [35, 40, 45]])

# %%
m[2]
# Out:
# array([35, 40, 45])

# %%
m[2][0]
# Out:
# 35

# %%
m[0:2]
# Out:
# array([[ 5, 10, 15],
#        [20, 25, 30]])

# %%
m[:]
# Out:
# array([[ 5, 10, 15],
#        [20, 25, 30],
#        [35, 40, 45]])

# %%
m[1:]
# Out:
# array([[20, 25, 30],
#        [35, 40, 45]])

# %%
m[:2]
# Out:
# array([[ 5, 10, 15],
#        [20, 25, 30]])

# %%
m[-1][0]
# Out:
# 35
