# %%
import random

a = random.randint(10, 20)
b = random.randint(10, 20)
c = a + b

print(a, b, c)
# Out:
# 10 14 24

# %%
pwd()
# Out:
# '/content'

# %%
# !ls ./drive/MyDrive
# Out:
#  clf_kl1.pkl	      clf_poly1.pkl	  'Colab Notebooks'   YuuDrive
#  clf_linearSVC1.pkl   clf_rbf1.pkl	   DTree_model.pkl    【Y̳u̳u̳D̳r̳i̳v̳e̳】
#  clf_NuSVC1.pkl       clf_svr_linear.pkl   gun_deaths.csv

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img = mpimg.imread('./drive/MyDrive/Popcat.png')
plt.imshow(img)

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)

# %%
import numpy as np
a = np.array([45, 23, 56])
print(a)
a.shape, a.ndim, a.dtype
# Out:
# [45 23 56]
# ((3,), 1, dtype('int64'))

# %% [markdown]
# import numpy as np
# import pandas as pd
#
# pool1 = pd.Series([1,2,3,4], ['USA','Britain','France','Germany'])
# pool1

# %%
import numpy as np
import pandas as pd

pool1 = pd.Series([1,2,3,4], ['USA','Britain','France','Germany'])
pool1
# Out:
# USA        1
# Britain    2
# France     3
# Germany    4
# dtype: int64

# %%
pool2 = pd.Series([1,2,3,4], ['USA','Britain','France','Germany'])
pool3 = pd.Series([1,2,3,4], ['USA','USSR','France','Germany'])
pool4 = pd.Series([10,20,30,40], ['USA','Britain','France','Germany'])
pool2
# Out:
# USA        1
# Britain    2
# France     3
# Germany    4
# dtype: int64

# %%
d_pool = pool1 + pool2
d_pool
# Out:
# USA        2
# Britain    4
# France     6
# Germany    8
# dtype: int64

# %%
m_pool = pool1+pool3
m_pool
# Out:
# Britain    NaN
# France     6.0
# Germany    8.0
# USA        2.0
# USSR       NaN
# dtype: float64

# %%
f_pool=pool1+pool4
f_pool
# Out:
# USA        11
# Britain    22
# France     33
# Germany    44
# dtype: int64

# %%
df = pd.DataFrame([pool1])
df
# Out:
#    USA  Britain  France  Germany
# 0    1        2       3        4

# %%
index = 'W1 W2'.split()
new_df=pd.DataFrame([pool1, pool2], index)
new_df
# Out:
#     USA  Britain  France  Germany
# W1    1        2       3        4
# W2    1        2       3        4

# %%
array = np.arange(1,21).reshape(5,4)
rlabel='A B C D E'.split()
clabel='odd1 even1 odd2 even2'.split()
df = pd.DataFrame(array, rlabel, clabel)
df
# Out:
#    odd1  even1  odd2  even2
# A     1      2     3      4
# B     5      6     7      8
# C     9     10    11     12
# D    13     14    15     16
# E    17     18    19     20

# %%
df['odd_sum']=df['odd1'] + df['odd2']
df['even_sum']=df['even1'] + df['even2']
df
# Out:
#    odd1  even1  odd2  even2  odd_sum  even_sum
# A     1      2     3      4        4         6
# B     5      6     7      8       12        14
# C     9     10    11     12       20        22
# D    13     14    15     16       28        30
# E    17     18    19     20       36        38

# %%
df['disposable'] = np.zeros(5)
df
# Out:
#    odd1  even1  odd2  even2  odd_sum  even_sum  disposable
# A     1      2     3      4        4         6         0.0
# B     5      6     7      8       12        14         0.0
# C     9     10    11     12       20        22         0.0
# D    13     14    15     16       28        30         0.0
# E    17     18    19     20       36        38         0.0

# %%
df.drop('disposable', axis=1, inplace=True)
df
# Out:
#    odd1  even1  odd2  even2  odd_sum  even_sum
# A     1      2     3      4        4         6
# B     5      6     7      8       12        14
# C     9     10    11     12       20        22
# D    13     14    15     16       28        30
# E    17     18    19     20       36        38

# %%
df[df>5]
# Out:
#    odd1  even1  odd2  even2  odd_sum  even_sum
# A   NaN    NaN   NaN    NaN      NaN         6
# B   NaN    6.0   7.0    8.0     12.0        14
# C   9.0   10.0  11.0   12.0     20.0        22
# D  13.0   14.0  15.0   16.0     28.0        30
# E  17.0   18.0  19.0   20.0     36.0        38

# %%
df[df['odd1'] !=9]
# Out:
#    odd1  even1  odd2  even2  odd_sum  even_sum
# A     1      2     3      4        4         6
# B     5      6     7      8       12        14
# D    13     14    15     16       28        30
# E    17     18    19     20       36        38

# %%
dic = { 'X':[1,2,np.nan], 'Y':[4,np.nan,np.nan], 'Z':[7,8,9] }
dic
# Out:
# {'X': [1, 2, nan], 'Y': [4, nan, nan], 'Z': [7, 8, 9]}

# %%
rLabel = 'A B C'.split()
df=pd.DataFrame(dic, rLabel)
df
# Out:
#      X    Y  Z
# A  1.0  4.0  7
# B  2.0  NaN  8
# C  NaN  NaN  9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, A to C
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X       2 non-null      float64
#  1   Y       1 non-null      float64
#  2   Z       3 non-null      int64
# dtypes: float64(2), int64(1)
# memory usage: 204.0+ bytes

# %%
df.isnull().sum()
# Out:
# X    1
# Y    2
# Z    0
# dtype: int64

# %%
df.dropna()
# Out:
#      X    Y  Z
# A  1.0  4.0  7

# %%
df.dropna(axis=1)
# Out:
#    Z
# A  7
# B  8
# C  9

# %%
df.fillna('0.0')
# Out:
#      X    Y  Z
# A  1.0  4.0  7
# B  2.0  0.0  8
# C  0.0  0.0  9

# %%
xmean = df['X'].mean()
df['X'].fillna(xmean)
# Out:
# A    1.0
# B    2.0
# C    1.5
# Name: X, dtype: float64

# %%
for i in 'X Y Z'.split():
  df[i].fillna(df[i].mean(), inplace=True)
df
# Out:
#      X    Y  Z
# A  1.0  4.0  7
# B  2.0  4.0  8
# C  1.5  4.0  9

# %%
import pandas as pd

data = {'person' : 'user1 user2 user3 user4 user5 user6'.split(),
        'product': 'HP HP Apple Apple Dell Dell'.split(),
        'sales' : [200, 120, 340, 124, 243, 350]}
serial = list(range(1,7))
df = pd.DataFrame(data, index=serial) # Changed serial to index=serial
df
# Out:
#   person product  sales
# 1  user1      HP    200
# 2  user2      HP    120
# 3  user3   Apple    340
# 4  user4   Apple    124
# 5  user5    Dell    243
# 6  user6    Dell    350

# %%
df.groupby('product').sum()
# Out:
#              person  sales
# product
# Apple    user3user4    464
# Dell     user5user6    593
# HP       user1user2    320

# %%
df.groupby('product').count()
# Out:
#          person  sales
# product
# Apple         2      2
# Dell          2      2
# HP            2      2

# %%
df.groupby('product').describe()
# Out:
#         sales
#         count   mean         std    min     25%    50%     75%    max
# product
# Apple     2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0
# Dell      2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# HP        2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
