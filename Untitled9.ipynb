# %%
#다중선형 회귀(수정된거)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# 데이터 불러오기
gun_deaths = pd.read_csv('gun_deaths.csv')

# race, intent, place, education, sex 열을 숫자로 매핑
gun_deaths.loc[:, 'race'] = gun_deaths['race'].map({'White': 1, 'Black': 2, 'Asian': 3, 'Native American/Native Alaskan': 4, 'Hispanic': 5})
gun_deaths.loc[:, 'intent'] = gun_deaths['intent'].map({'Suicide': 1, 'Undetermined': 2, 'Accidental': 3, 'NA': 4, 'Homicide': 5})
gun_deaths.loc[:, 'place'] = gun_deaths['place'].map({'Home': 1, 'Street': 2, 'Other specified': 3, 'NA': 4, 'Other unspecified': 5, 'Trade/service area': 6, 'Farm': 7})
gun_deaths.loc[:, 'education'] = gun_deaths['education'].map({'BA': 1, 'Less than HS': 2, 'HS/GED': 3, 'Some college': 4})
gun_deaths.loc[:, 'sex'] = gun_deaths['sex'].map({'M': 1, 'F': 2})

# feature와 Intent에 누락된 값을 처리한 후 변환된 값을 할당
feature = gun_deaths[['race', 'intent', 'place', 'education', 'sex', 'month', 'age']]
feature = feature.fillna(feature.mean())  # 누락된 값은 각 열의 평균 값으로 대체

# 'age' 열의 NaN 값을 중앙값으로 대체
place_median = gun_deaths['place'].median()
gun_deaths['place'].fillna(place_median, inplace=True)

# 다시 학습 데이터와 테스트 데이터로 분할
feature_train, feature_test, Age_train, Age_test = train_test_split(feature, gun_deaths['place'], test_size=0.001, random_state=10)

# 선형 회귀 모델 학습
rege = LinearRegression()
rege.fit(feature_train, Age_train)

# 테스트 데이터에 대한 예측
Age_pred = rege.predict(feature_test)

Age_test = Age_test.to_numpy()

# 시각화
plt.figure(figsize=(10, 5))
plt.plot(Age_test, label='Place_test')
plt.plot(Age_pred, label='Place_pred')
plt.legend(loc='upper center')
plt.show()
# Out:
# <ipython-input-1-58a6ffb03bee>:13: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   gun_deaths.loc[:, 'race'] = gun_deaths['race'].map({'White': 1, 'Black': 2, 'Asian': 3, 'Native American/Native Alaskan': 4, 'Hispanic': 5})
# <ipython-input-1-58a6ffb03bee>:14: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   gun_deaths.loc[:, 'intent'] = gun_deaths['intent'].map({'Suicide': 1, 'Undetermined': 2, 'Accidental': 3, 'NA': 4, 'Homicide': 5})
# <ipython-input-1-58a6ffb03bee>:15: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   gun_deaths.loc[:, 'place'] = gun_deaths['place'].map({'Home': 1, 'Street': 2, 'Other specified': 3, 'NA': 4, 'Other unspecified': 5, 'Trade/service area': 6, 'Farm': 7})
# <ipython-input-1-58a6ffb03bee>:16: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   gun_deaths.loc[:, 'education'] = gun_deaths['education'].map({'BA': 1, 'Less than HS': 2, 'HS/GED': 3, 'Some college': 4})
# <ipython-input-1-58a6ffb03bee>:17: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   gun_deaths.loc[:, 'sex'] = gun_deaths['sex'].map({'M': 1, 'F': 2})
